# %%
import sys
import os

# Add the parent directory to the path so the package is importable
sys.path.append(os.path.abspath(".."))

import jupyter_helper_functions
import pandas as pd
from pprint import pprint

# %%
# Load datasets using helper functions
corrupt_dataset = jupyter_helper_functions.load_dataset("../datasets/parker_datasets/allergen/allergen_corrupted_first1000.csv")
gold_standard = jupyter_helper_functions.load_dataset("../datasets/parker_datasets/allergen/allergen_cleaned_gold_first1000.csv")
repaired_dataset = jupyter_helper_functions.load_dataset("../analysis/repairs/allergen/merged_dataset_gemini_2_0_flash_lite_50_rows_context_combined_option_3.csv")

# Reindex columns to match corrupt_dataset
repaired_dataset = repaired_dataset.reindex(columns=corrupt_dataset.columns)
corrupt_dataset = corrupt_dataset.sort_values(by="code").reset_index(drop=True)
gold_standard = gold_standard.sort_values(by="code").reset_index(drop=True)
repaired_dataset = repaired_dataset.sort_values(by="code").reset_index(drop=True)

# Check if all three dataframes have the exact same row order
same_order = (
    (corrupt_dataset['code'] == gold_standard['code']).all() and
    (corrupt_dataset['code'] == repaired_dataset['code']).all()
)
print("All dataframes have the exact same row order:", same_order)
# Out:
# All dataframes have the exact same row order: True

# %%
micro_stats = jupyter_helper_functions.Pipeline.evaluate_micro(
    gold_standard=gold_standard,
    corrupted_dataset=corrupt_dataset,
    cleaned_dataset=repaired_dataset,
)

pprint(micro_stats)
jupyter_helper_functions.save_json(
    micro_stats,
    "../analysis/results/allergen/gemini_2_0_flash_lite_50_rows_context_option_3_results_micro.json",
)
# Out:
# {'accuracy': 0.939541041482789,
#  'column_names': ['code',
#                   'nuts',
#                   'almondnuts',
#                   'brazil_nuts',
#                   'macadamia_nuts',
#                   'hazelnut',
#                   'pistachio',
#                   'walnut',
#                   'cashew',
#                   'celery',
#                   'crustaceans',
#                   'eggs',
#                   'fish',
#                   'gluten',
#                   'lupin',
#                   'milk',
#                   'molluscs',
#                   'mustard',
#                   'peanut',
#                   'sesame',
#                   'soy',
#                   'sulfite'],
#  'f1_score': 0.45418326693227085,
#  'false_negative': 244,
#  'false_negative_rate': 0.6815642458100558,
#  'false_positive': 30,
#  'false_positive_rate': 0.007187350263536177,
#  'num_columns': 22,
#  'num_rows': 206,
#  'precision': 0.7916666666666666,
#  'recall': 0.31843575418994413,
#  'true_negative': 4144,
#  'true_positive': 114}

# %%
macro_stats = jupyter_helper_functions.Pipeline.evaluate_macro(
    gold_standard=gold_standard,
    corrupted_dataset=corrupt_dataset,
    cleaned_dataset=repaired_dataset,
)

pprint(macro_stats)

jupyter_helper_functions.save_json(
    macro_stats,
    "../analysis/results/allergen/gemini_2_0_flash_lite_50_rows_context_option_3_results_macro.json",
)
# Out:
# {'column_names': ['code',
#                   'nuts',
#                   'almondnuts',
#                   'brazil_nuts',
#                   'macadamia_nuts',
#                   'hazelnut',
#                   'pistachio',
#                   'walnut',
#                   'cashew',
#                   'celery',
#                   'crustaceans',
#                   'eggs',
#                   'fish',
#                   'gluten',
#                   'lupin',
#                   'milk',
#                   'molluscs',
#                   'mustard',
#                   'peanut',
#                   'sesame',
#                   'soy',
#                   'sulfite'],
#  'num_columns': 22,
#  'num_rows': 206,
#  'stats': [{'accuracy': 1.0,
#             'column_name': 'code',
#             'f1_score': 0.0,
#             'false_negative': 0,
#             'false_negative_rate': 0.0,
#             'false_positive': 0,
#             'false_positive_rate': 0.0,
#             'num_entries': 206,
#             'precision': 0.0,
#             'recall': 0.0,
#             'true_negative': 206,
#             'true_positive': 0},
#            {'accuracy': 0.8932038834951457,
#             'column_name': 'nuts',
#             'f1_score': 0.6764705882352942,
#             'false_negative': 18,
#             'false_negative_rate': 0.43902439024390244,
#             'false_positive': 4,
#             'false_positive_rate': 0.024242424242424242,
#             'num_entries': 206,
#             'precision': 0.8518518518518519,
#             'recall': 0.5609756097560976,
#             'true_negative': 161,
#             'true_positive': 23},
#            {'accuracy': 0.6019417475728155,
#             'column_name': 'almondnuts',
#             'f1_score': 0.02380952380952381,
#             'false_negative': 82,
#             'false_negative_rate': 0.9879518072289156,
#             'false_positive': 0,
#             'false_positive_rate': 0.0,
#             'num_entries': 206,
#             'precision': 1.0,
#             'recall': 0.012048192771084338,
#             'true_negative': 123,
#             'true_positive': 1},
#            {'accuracy': 0.9611650485436893,
#             'column_name': 'brazil_nuts',
#             'f1_score': 0.0,
#             'false_negative': 8,
#             'false_negative_rate': 1.0,
#             'false_positive': 0,
#             'false_positive_rate': 0.0,
#             'num_entries': 206,
#             'precision': 0.0,
#             'recall': 0.0,
#             'true_negative': 198,
#             'true_positive': 0},
#            {'accuracy': 0.970873786407767,
#             'column_name': 'macadamia_nuts',
#             'f1_score': 0.0,
#             'false_negative': 6,
#             'false_negative_rate': 1.0,
#             'false_positive': 0,
#             'false_positive_rate': 0.0,
#             'num_entries': 206,
#             'precision': 0.0,
#             'recall': 0.0,
#             'true_negative': 200,
#             'true_positive': 0},
#            {'accuracy': 0.9223300970873787,
#             'column_name': 'hazelnut',
#             'f1_score': 0.42857142857142855,
#             'false_negative': 15,
#             'false_negative_rate': 0.7142857142857143,
#             'false_positive': 1,
#             'false_positive_rate': 0.005405405405405406,
#             'num_entries': 206,
#             'precision': 0.8571428571428571,
#             'recall': 0.2857142857142857,
#             'true_negative': 184,
#             'true_positive': 6},
#            {'accuracy': 0.9611650485436893,
#             'column_name': 'pistachio',
#             'f1_score': 0.0,
#             'false_negative': 8,
#             'false_negative_rate': 1.0,
#             'false_positive': 0,
#             'false_positive_rate': 0.0,
#             'num_entries': 206,
#             'precision': 0.0,
#             'recall': 0.0,
#             'true_negative': 198,
#             'true_positive': 0},
#            {'accuracy': 0.941747572815534,
#             'column_name': 'walnut',
#             'f1_score': 0.0,
#             'false_negative': 12,
#             'false_negative_rate': 1.0,
#             'false_positive': 0,
#             'false_positive_rate': 0.0,
#             'num_entries': 206,
#             'precision': 0.0,
#             'recall': 0.0,
#             'true_negative': 194,
#             'true_positive': 0},
#            {'accuracy': 0.8932038834951457,
#             'column_name': 'cashew',
#             'f1_score': 0.0,
#             'false_negative': 22,
#             'false_negative_rate': 1.0,
#             'false_positive': 0,
#             'false_positive_rate': 0.0,
#             'num_entries': 206,
#             'precision': 0.0,
#             'recall': 0.0,
#             'true_negative': 184,
#             'true_positive': 0},
#            {'accuracy': 0.941747572815534,
#             'column_name': 'celery',
#             'f1_score': 0.45454545454545453,
#             'false_negative': 9,
#             'false_negative_rate': 0.6428571428571429,
#             'false_positive': 3,
#             'false_positive_rate': 0.015625,
#             'num_entries': 206,
#             'precision': 0.625,
#             'recall': 0.35714285714285715,
#             'true_negative': 189,
#             'true_positive': 5},
#            {'accuracy': 1.0,
#             'column_name': 'crustaceans',
#             'f1_score': 0.0,
#             'false_negative': 0,
#             'false_negative_rate': 0.0,
#             'false_positive': 0,
#             'false_positive_rate': 0.0,
#             'num_entries': 206,
#             'precision': 0.0,
#             'recall': 0.0,
#             'true_negative': 206,
#             'true_positive': 0},
#            {'accuracy': 1.0,
#             'column_name': 'eggs',
#             'f1_score': 1.0,
#             'false_negative': 0,
#             'false_negative_rate': 0.0,
#             'false_positive': 0,
#             'false_positive_rate': 0.0,
#             'num_entries': 206,
#             'precision': 1.0,
#             'recall': 1.0,
#             'true_negative': 201,
#             'true_positive': 5},
#            {'accuracy': 1.0,
#             'column_name': 'fish',
#             'f1_score': 0.0,
#             'false_negative': 0,
#             'false_negative_rate': 0.0,
#             'false_positive': 0,
#             'false_positive_rate': 0.0,
#             'num_entries': 206,
#             'precision': 0.0,
#             'recall': 0.0,
#             'true_negative': 206,
#             'true_positive': 0},
#            {'accuracy': 0.941747572815534,
#             'column_name': 'gluten',
#             'f1_score': 0.76,
#             'false_negative': 9,
#             'false_negative_rate': 0.32142857142857145,
#             'false_positive': 3,
#             'false_positive_rate': 0.016853932584269662,
#             'num_entries': 206,
#             'precision': 0.8636363636363636,
#             'recall': 0.6785714285714286,
#             'true_negative': 175,
#             'true_positive': 19},
#            {'accuracy': 0.9805825242718447,
#             'column_name': 'lupin',
#             'f1_score': 0.33333333333333337,
#             'false_negative': 4,
#             'false_negative_rate': 0.8,
#             'false_positive': 0,
#             'false_positive_rate': 0.0,
#             'num_entries': 206,
#             'precision': 1.0,
#             'recall': 0.2,
#             'true_negative': 201,
#             'true_positive': 1},
#            {'accuracy': 0.9514563106796117,
#             'column_name': 'milk',
#             'f1_score': 0.8,
#             'false_negative': 8,
#             'false_negative_rate': 0.2857142857142857,
#             'false_positive': 2,
#             'false_positive_rate': 0.011235955056179775,
#             'num_entries': 206,
#             'precision': 0.9090909090909091,
#             'recall': 0.7142857142857143,
#             'true_negative': 176,
#             'true_positive': 20},
#            {'accuracy': 1.0,
#             'column_name': 'molluscs',
#             'f1_score': 0.0,
#             'false_negative': 0,
#             'false_negative_rate': 0.0,
#             'false_positive': 0,
#             'false_positive_rate': 0.0,
#             'num_entries': 206,
#             'precision': 0.0,
#             'recall': 0.0,
#             'true_negative': 206,
#             'true_positive': 0},
#            {'accuracy': 0.941747572815534,
#             'column_name': 'mustard',
#             'f1_score': 0.25000000000000006,
#             'false_negative': 9,
#             'false_negative_rate': 0.8181818181818182,
#             'false_positive': 3,
#             'false_positive_rate': 0.015384615384615385,
#             'num_entries': 206,
#             'precision': 0.4,
#             'recall': 0.18181818181818182,
#             'true_negative': 192,
#             'true_positive': 2},
#            {'accuracy': 0.9320388349514563,
#             'column_name': 'peanut',
#             'f1_score': 0.4166666666666667,
#             'false_negative': 10,
#             'false_negative_rate': 0.6666666666666666,
#             'false_positive': 4,
#             'false_positive_rate': 0.020942408376963352,
#             'num_entries': 206,
#             'precision': 0.5555555555555556,
#             'recall': 0.3333333333333333,
#             'true_negative': 187,
#             'true_positive': 5},
#            {'accuracy': 0.9223300970873787,
#             'column_name': 'sesame',
#             'f1_score': 0.6363636363636364,
#             'false_negative': 12,
#             'false_negative_rate': 0.46153846153846156,
#             'false_positive': 4,
#             'false_positive_rate': 0.022222222222222223,
#             'num_entries': 206,
#             'precision': 0.7777777777777778,
#             'recall': 0.5384615384615384,
#             'true_negative': 176,
#             'true_positive': 14},
#            {'accuracy': 0.912621359223301,
#             'column_name': 'soy',
#             'f1_score': 0.5909090909090909,
#             'false_negative': 12,
#             'false_negative_rate': 0.48,
#             'false_positive': 6,
#             'false_positive_rate': 0.03314917127071823,
#             'num_entries': 206,
#             'precision': 0.6842105263157895,
#             'recall': 0.52,
#             'true_negative': 175,
#             'true_positive': 13},
#            {'accuracy': 1.0,
#             'column_name': 'sulfite',
#             'f1_score': 0.0,
#             'false_negative': 0,
#             'false_negative_rate': 0.0,
#             'false_positive': 0,
#             'false_positive_rate': 0.0,
#             'num_entries': 206,
#             'precision': 0.0,
#             'recall': 0.0,
#             'true_negative': 206,
#             'true_positive': 0}]}
